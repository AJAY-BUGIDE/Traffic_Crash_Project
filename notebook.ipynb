# %%
from src.analysis import top_streets

df = top_streets()

print(df.head())
# Out:
#    STREET_NAME  total_crashes
# 0  WESTERN AVE          18377
# 1   PULASKI RD          16072
# 2   CICERO AVE          15291
# 3  ASHLAND AVE          14502
# 4   HALSTED ST          12838
